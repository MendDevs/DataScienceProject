# %% [markdown]
# # Persona : Hugo Martin
#
# ## Profil général
# - **Nom :** Hugo Martin
# - **Âge :** 26 ans
# - **Situation :** Jeune cadre dynamique, diplômé en Data & IA, travaillant à Lyon
# - **Objectif personnel :** Premier investissement immobilier locatif pour générer des revenus complémentaires
# - **Apport disponible :** 30 000 €
# - **Budget global :** 200 000 € (avec prêt)
# - **Stratégie :** Acheter un appartement dans une ville à fort potentiel touristique ou étudiant pour Airbnb à l’année
# - **Niveau de connaissance :** Très à l’aise avec les outils numériques, débutant en investissement immobilier
# - **Contraintes :** Rendement locatif brut ≥ 7%, éviter zones saturées ou trop chères
#
# ---
#
# ## Besoins et objectifs d’Hugo
#
# | # | Besoin | Objectif associé |
# |---|--------|-----------------|
# | 1 | Identifier les villes françaises les plus rentables pour Airbnb | Maximiser la rentabilité locative |
# | 2 | Connaître les prix moyens au m² selon les villes et types de biens | Vérifier la faisabilité selon budget total (200 000 € max) |
# | 3 | Analyser l’évolution des prix immobiliers sur 5 ans | Identifier zones à potentiel pour un gain à long terme |
# | 4 | Estimer le rendement locatif brut et net (revenus Airbnb / prix d’achat) | Comparer rentabilité réelle par ville |
# | 5 | Identifier les types de biens les plus rentables pour location courte durée | Choisir le format de bien le plus performant pour Airbnb |
# | 6 | Repérer les zones attractives (touristiques ou étudiantes) | Sécuriser un bon taux d’occupation toute l’année |
# | 7 | Repérer les zones à éviter (prix stables ou en baisse, saturation Airbnb) | Limiter le risque d’investissement |
# | 8 | Visualiser les opportunités sur une carte interactive | Explorer les zones géographiquement et intuitivement |
# | 9 | Recevoir une recommandation automatique selon budget et rendement cible (≥7%) | Prioriser les villes correspondant aux critères financiers |
# | 10 | Simuler la rentabilité selon différents scénarios (prix/nuit, taux d’occupation, charges) | Ajuster stratégie et estimer revenus potentiels |
