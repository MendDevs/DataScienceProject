# %%
# 🏠 Projet Data Science : Analyse du Marché Immobilier pour Investisseurs Airbnb

---

## 1️⃣ Contexte et Objectifs

L'objectif de ce projet est de mettre en pratique les compétences en **data science** acquises au cours de la formation.  
En utilisant des fichiers de données foncières publiques (DVF), nous allons créer une solution utile pour un **investisseur Airbnb**.  

Le notebook permettra de :
- Explorer et analyser le marché immobilier.  
- Visualiser les tendances des prix et types de biens.  
- Produire des recommandations pour investir de manière rentable.

---

## 2️⃣ Persona : Alexandre Morel

### Profil Général
- **Nom :** Alexandre Morel  
- **Âge :** 34 ans  
- **Situation :** Entrepreneur indépendant  
- **Localisation :** Lyon, France  
- **Objectif :** Investir dans des biens pour la location courte durée (Airbnb)  

### Contexte et motivations
Alexandre souhaite diversifier ses revenus en achetant 1 à 2 biens Airbnb.  
Il veut maximiser la rentabilité nette et identifier les zones à fort potentiel.

### Besoins / Objectifs
| # | Besoin | Comment le notebook aide |
|---|--------|--------------------------|
| 1 | Identifier villes les plus rentables | Classement interactif selon rendement locatif |
| 2 | Zones à forte demande touristique | Graphique basé sur volume de transactions et prix/m² |
| 3 | Variation saisonnière des prix | Graphique temporel par mois/trimestre |
| 4 | Comparer studio vs T2 vs T3 | Bar chart interactif |
| 5 | Estimer rendement locatif brut | Calcul automatique |
| 6 | Identifier zones à éviter | Carte ou tableau filtrable |
| 7 | Visualiser tendances prix 5 ans | Graphique de tendance |
| 8 | Voir biens les plus recherchés | Histogramme interactif |
| 9 | Intégrer données externes | API ou dataset additionnel |
| 10 | Carte interactive des opportunités Airbnb | Carte Folium ou Plotly |

---

## 3️⃣ Sources de données recommandées

- **DVF (Demandes de valeurs foncières)** : prix, surface, type de bien  
  [https://www.data.gouv.fr/fr/datasets/demandes-de-valeurs-foncieres/](https://www.data.gouv.fr/fr/datasets/demandes-de-valeurs-foncieres/)
- **INSEE** : population, revenu moyen, taux de vacance  
- **Données tourisme** : fréquentation touristique par ville  
- **Optionnel** : AirDNA ou InsideAirbnb pour demande réelle Airbnb  

---

## 4️⃣ Plan du projet

1. **Préparation des données** (`02_Data_Preparation.ipynb`)  
   - Nettoyage des fichiers DVF  
   - Transformation des variables, calculs de prix/m², rendement  

2. **Exploration des données** (`03_Data_Exploration.ipynb`)  
   - Analyse statistique et tendances régionales  
   - Identification des biens les plus rentables  

3. **Visualisations et widgets interactifs** (`04_Data_Visualisation_and_Widgets.ipynb`)  
   - Graphiques interactifs et cartes  
   - Comparaison entre villes, types de biens et budgets  

4. **Conclusions et recommandations** (`05_Conclusions_and_Recommendations.ipynb`)  
   - Synthèse pour l’investisseur  
   - Recommandations pratiques pour investir dans Airbnb  

---

## 5️⃣ Import des bibliothèques Python

```python
# Manipulation des données
import pandas as pd
import numpy as np

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import folium

# Widgets interactifs (optionnel)
from ipywidgets import interact, widgets

# Réglages de visualisation
# %matplotlib inline
sns.set(style="whitegrid")
